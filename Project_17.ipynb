# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.shape
# Out:
# (7668, 15)

# %%
df['budget'].replace(np.nan, df['budget'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# name          0
# rating       77
# genre         0
# year          0
# released      2
# score         3
# votes         3
# director      0
# writer        3
# star          1
# country       3
# budget        0
# gross       189
# company      17
# runtime       4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7412 entries, 0 to 7659
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7412 non-null   object
#  1   rating    7412 non-null   object
#  2   genre     7412 non-null   object
#  3   year      7412 non-null   int64
#  4   released  7412 non-null   object
#  5   score     7412 non-null   float64
#  6   votes     7412 non-null   float64
#  7   director  7412 non-null   object
#  8   writer    7412 non-null   object
#  9   star      7412 non-null   object
#  10  country   7412 non-null   object
#  11  budget    7412 non-null   float64
#  12  gross     7412 non-null   float64
#  13  company   7412 non-null   object
#  14  runtime   7412 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 926.5+ KB

# %%
df['gross']=df['gross'].astype(int)

# %%
df['budget']=df['budget'].astype(int)

# %%
import pandas as pd
df['released']=df['released'].astype(str).str[:4]

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'released_clean', 'released_corrected'],
#       dtype='object')

# %%
df.drop(['released_clean', 'released_corrected'], axis=1, inplace=True)

# %%
df[['budget', 'released']]
# Out:
#          budget released
# 0      19000000     June
# 1       4500000     July
# 2      18000000     June
# 3       3500000     July
# 4       6000000     July
# ...         ...      ...
# 7651  135000000     Febr
# 7652   80000000     Augu
# 7653   20000000     Apri
# 7656   20000000     June
# 7659   20000000     Marc
#
# [7412 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df['gross'].max()
# Out:
# 2847246203

# %%
df['gross'].min()
# Out:
# 309

# %%
sns.regplot(data=df, x='budget', y='gross', line_kws={"color":"red"})
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['writer_encoded'] = le.fit_transform(df['writer'])
df['star_encoded'] = le.fit_transform(df['star'])

# Now calculate correlation
df[['writer_encoded', 'star_encoded', 'budget', 'gross']].corr()
# Out:
#                 writer_encoded  star_encoded    budget     gross
# writer_encoded        1.000000      0.024161 -0.030993 -0.024021
# star_encoded          0.024161      1.000000 -0.020941 -0.002451
# budget               -0.030993     -0.020941  1.000000  0.746657
# gross                -0.024021     -0.002451  0.746657  1.000000

# %%
numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'writer_encoded', 'star_encoded'],
#       dtype='object')

# %%
df['company'].unique()
# Out:
# array(['Warner Bros.', 'Columbia Pictures', 'Lucasfilm', ...,
#        'Beijing Diqi Yinxiang Entertainment', 'Prowess Pictures',
#        'Pryor Entertainment'], dtype=object)
