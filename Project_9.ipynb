# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/superstore_dataset2011-2015.csv', encoding='ISO-8859-1')

# %%
df.head(5)
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
df.tail(5)
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035.0    263
# 10024.0    230
# 10009.0    229
# 94122.0    203
# 10011.0    193
#           ...
# 59102.0      1
# 29730.0      1
# 93405.0      1
# 59801.0      1
# 77536.0      1
# Name: count, Length: 631, dtype: int64

# %%
df['Postal Code'].shape
# Out:
# (51290,)

# %%
df['Postal Code'].isnull().sum()
# Out:
# np.int64(41296)

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.drop(['Row ID', 'Order ID','Postal Code','Customer ID'], axis=1,inplace =True)

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# Hypothesis 1
cat_pro=df.groupby('Category')['Profit'].sum().reset_index()
cat_pro
# Out:
#           Category        Profit
# 0        Furniture  285204.72380
# 1  Office Supplies  518473.83430
# 2       Technology  663778.73318

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cat = ['Furniture', 'Office Supplies', 'Technology']
pro = [285204.72380, 518473.83430, 663778.73318]
colors = sns.color_palette('Set3', n_colors=len(cat))  # manually get colors

plt.figure(figsize=(15, 4))
plt.pie(pro, labels=cat, autopct='%1.1f%%', colors=colors)  # use colors instead of palette

plt.title('Profit by Category')
plt.tight_layout()
plt.show()

# %%
df['Region'].unique()
# Out:
# array(['Africa', 'Oceania', 'EMEA', 'North', 'Central Asia', 'West',
#        'North Asia', 'Central', 'South', 'Canada', 'Southeast Asia',
#        'East', 'Caribbean'], dtype=object)

# %%
reg_sales=df.groupby('Region')['Sales'].sum().reset_index()

# %%
reg_sales
# Out:
#             Region         Sales
# 0           Africa  7.837732e+05
# 1           Canada  6.692817e+04
# 2        Caribbean  3.242809e+05
# 3          Central  2.822303e+06
# 4     Central Asia  7.528266e+05
# 5             EMEA  8.061613e+05
# 6             East  6.787812e+05
# 7            North  1.248166e+06
# 8       North Asia  8.483098e+05
# 9          Oceania  1.100185e+06
# 10           South  1.600907e+06
# 11  Southeast Asia  8.844232e+05
# 12            West  7.254578e+05

# %%
plt.figure(figsize=(15, 4))
sns.barplot(data=reg_sales, x='Region', y='Sales', palette='Set2')
plt.grid()
plt.title('Sales by Region')  # Optional, but good for readability
plt.xlabel('Region')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.show()
# Out:
# /tmp/ipython-input-1689277885.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=reg_sales, x='Region', y='Sales', palette='Set2')

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')  # handles bad formats too
df['Order_Month'] = df['Order Date'].dt.month

# %%
Mon_sal = df.groupby('Order_Month')['Sales'].sum().reset_index()

plt.figure(figsize=(15, 4))
sns.lineplot(data=Mon_sal, x='Order_Month', y='Sales')
plt.grid()
plt.title('Sales by Month')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
Mon_sal
# Out:
#     Order_Month         Sales
# 0           1.0  364011.36458
# 1           2.0  417490.25280
# 2           3.0  443014.04030
# 3           4.0  429860.59638
# 4           5.0  389524.66610
# 5           6.0  382443.27476
# 6           7.0  397335.61740
# 7           8.0  435505.90478
# 8           9.0  373335.36426
# 9          10.0  399644.87072
# 10         11.0  439218.48130
# 11         12.0  394138.40022

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Order_Month'],
#       dtype='object')

# %%
df.groupby('Ship Mode')['Quantity'].sum().reset_index()
# Out:
#         Ship Mode  Quantity
# 0     First Class     26039
# 1        Same Day      9230
# 2    Second Class     35724
# 3  Standard Class    107319

# %%
shi_m = ['First Class	', 'Same Day', 'Second Class	','Standard Class']
Qun = [26039,9230, 35724,107319
]
colors = sns.color_palette('Set3', n_colors=len(shi_m))  # manually get colors

plt.figure(figsize=(15, 4))
plt.pie(Qun, labels=shi_m, autopct='%1.1f%%', colors=colors)  # use colors instead of palette

plt.title('Profit by Category')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3626079403.py:10: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Order_Month'],
#       dtype='object')

# %%
# Return percentage
returned_per_by_shipping_mode = (return_orders_by_shipping_mode / total_orders_by_shipping_mode) * 100
# Reset index to turn Series into DataFrame for plotting
returned_df = returned_per_by_shipping_mode.reset_index()
returned_df.columns = ['Ship Mode', 'Return Percentage']

plt.figure(figsize=(15, 4))
sns.barplot(data=returned_df, x='Ship Mode', y='Return Percentage', palette='Set2')
plt.title('Return Percentage by Shipping Mode')
plt.ylabel('Return %')
plt.xlabel('Shipping Mode')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3655929314.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=returned_df, x='Ship Mode', y='Return Percentage', palette='Set2')

# %%
# Total orders per shipping mode
total_orders_by_shipping_mode = df.groupby('Ship Mode').size()

# Returned (negative profit) orders per shipping mode
return_orders_by_shipping_mode = df[df['Profit'] < 0].groupby('Ship Mode').size()

# Return percentage
returned_per_by_shipping_mode = (return_orders_by_shipping_mode / total_orders_by_shipping_mode) * 100

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Order_Month'],
#       dtype='object')

# %%
df['Order Day'] = df['Order Date'].dt.day_name()

# %%
df['Order Day']
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 51285         NaN
# 51286         NaN
# 51287         NaN
# 51288         NaN
# 51289         NaN
# Name: Order Day, Length: 51290, dtype: object

# %%
df['Order Day'].isnull().sum()
# Out:
# np.int64(31223)

# %%
day_pro=df.groupby(['Order Day'])['Profit'].sum().reset_index()
plt.grid()
plt.title('Profit by Day')

sns.barplot(data=day_pro, x='Order Day', y='Profit', palette='Set2')
plt.show()
# Out:
# /tmp/ipython-input-318524446.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=day_pro, x='Order Day', y='Profit', palette='Set2')
