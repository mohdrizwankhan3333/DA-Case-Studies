# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
# Display top 3 rows of the DS
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %%
df1.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df1.shape
# Out:
# (7, 3)

# %%
df1.shape[0]
# Out:
# 7

# %%
df1.info()
# use parenthesis where the calculation has been performed
# don't use parenthesis where the calculation is not performed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df1.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
df1.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
df1.describe(include='all')
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1['Gender'].nunique()
# Out:
# 2

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
len(df1[(df1['Marks'] >= 90) & (df1['Marks'] <= 100)])
# Out:
# 4

# %%
df1[(df1['Marks'] >= 90) & (df1['Marks'] <= 100)]['Marks'].sum()

df1['Marks'].sum()
# Out:
# np.int64(645)

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %%
(df1['Marks'].between(90, 100).sum())  # cleaner than using sum(...)
# Out:
# np.int64(4)

# %%
df1['Marks'].mean()
df1['Marks'].min()
# Out:
# 83

# %%
def marks(x):
  return x/3

# %%
df1['Marks'].apply(marks)
# Out:
# 0    32.666667
# 1    29.666667
# 2    33.000000
# 3    29.000000
# 4    30.000000
# 5    27.666667
# 6    33.000000
# Name: Marks, dtype: float64

# %%
df1['Marks'].apply(lambda x : x/3)
# Out:
# 0    32.666667
# 1    29.666667
# 2    33.000000
# 3    29.000000
# 4    30.000000
# 5    27.666667
# 6    33.000000
# Name: Marks, dtype: float64

# %%
df1['Marks'].apply(lambda x:x+4
                   )
# Out:
# 0    102
# 1     93
# 2    103
# 3     91
# 4     94
# 5     87
# 6    103
# Name: Marks, dtype: int64

# %%
df1['Gender1'
]=df1['Gender'
].map({'Male':1,'Female':0})

# %%
df1
# Out:
#       Name  Marks  Gender  Gender1
# 0  Priyang     98       1      NaN
# 1   Aadhya     89       0      NaN
# 2   Krisha     99       0      NaN
# 3   Vedant     87       1      NaN
# 4   Parshv     90       1      NaN
# 5   Mittal     83       0      NaN
# 6  Archana     99       0      NaN

# %%
df1.drop('Gender1',axis=1
         )
# Out:
#       Name  Marks  Gender
# 0  Priyang     98       1
# 1   Aadhya     89       0
# 2   Krisha     99       0
# 3   Vedant     87       1
# 4   Parshv     90       1
# 5   Mittal     83       0
# 6  Archana     99       0

# %%
df1.drop(['Gender1'],axis=1,inplace=True
         )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-96-3578040138.py in <cell line: 0>()
# ----> 1 df1.drop(['Gender1'],axis=1,inplace=True
#       2          )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df1.sort_values(by='Marks',ascending=1)
# Out:
#       Name  Marks  Gender
# 5   Mittal     83       0
# 3   Vedant     87       1
# 1   Aadhya     89       0
# 4   Parshv     90       1
# 0  Priyang     98       1
# 2   Krisha     99       0
# 6  Archana     99       0

# %%
df1[df1['Gender']=='Female'][['Name','Marks']]
# Out:
# Empty DataFrame
# Columns: [Name, Marks]
# Index: []

# %%
df1[df1['Gender'].isin(['Female'])][['Name', 'Marks']]
# Out:
# Empty DataFrame
# Columns: [Name, Marks]
# Index: []
