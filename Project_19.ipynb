# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/amazon.csv',encoding='latin1')

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df.shape
# Out:
# (6454, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
df['year'].astype(int)
# Out:
# 0       1998
# 1       1999
# 2       2000
# 3       2001
# 4       2002
#         ...
# 6449    2012
# 6450    2013
# 6451    2014
# 6452    2015
# 6453    2016
# Name: year, Length: 6454, dtype: int64

# %%
df['date']=pd.to_datetime(df['year'])
df.head()
# Out:
#    year state    month  number                          date
# 0  1998  Acre  Janeiro     0.0 1970-01-01 00:00:00.000001998
# 1  1999  Acre  Janeiro     0.0 1970-01-01 00:00:00.000001999
# 2  2000  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002000
# 3  2001  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002001
# 4  2002  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 252.2+ KB

# %%
df['year']=df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 252.2+ KB

# %%
df.head()
# Out:
#    year state    month  number                          date
# 0  1998  Acre  Janeiro     0.0 1970-01-01 00:00:00.000001998
# 1  1999  Acre  Janeiro     0.0 1970-01-01 00:00:00.000001999
# 2  2000  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002000
# 3  2001  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002001
# 4  2002  Acre  Janeiro     0.0 1970-01-01 00:00:00.000002002

# %%
df['month'] = df['month'].replace({
    'Janeiro': 'January',
    'Fevereiro': 'February',
    'Março': 'March',
    'Abril': 'April',
    'Maio': 'May',
    'Junho': 'June',
    'Julho': 'July',
    'Agosto': 'August',
    'Setembro': 'September',
    'Outubro': 'October',
    'Novembro': 'November',
    'Dezembro': 'December'
})

# %%
df['month']
# Out:
# 0        January
# 1        January
# 2        January
# 3        January
# 4        January
#           ...
# 6449    December
# 6450    December
# 6451    December
# 6452    December
# 6453    December
# Name: month, Length: 6454, dtype: object

# %%
df.describe()
# Out:
#               year       number                           date
# count  6454.000000  6454.000000                           6454
# mean   2007.461729   108.293163  1970-01-01 00:00:00.000002007
# min    1998.000000     0.000000  1970-01-01 00:00:00.000001998
# 25%    2002.000000     3.000000  1970-01-01 00:00:00.000002002
# 50%    2007.000000    24.000000  1970-01-01 00:00:00.000002007
# 75%    2012.000000   113.000000  1970-01-01 00:00:00.000002012
# max    2017.000000   998.000000  1970-01-01 00:00:00.000002017
# std       5.746654   190.812242                            NaN

# %%
df.isnull().sum()
# Out:
# year      0
# state     0
# month     0
# number    0
# date      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(32)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df2=df.groupby('state')['number'].sum().reset_index()

# %%
df2
# Out:
#                state     number
# 0               Acre  18464.030
# 1            Alagoas   4606.000
# 2              Amapa  21831.576
# 3           Amazonas  30650.129
# 4              Bahia  44746.226
# 5              Ceara  30428.063
# 6   Distrito Federal   3561.000
# 7     Espirito Santo   6546.000
# 8              Goias  37695.520
# 9           Maranhao  25129.131
# 10       Mato Grosso  96246.028
# 11      Minas Gerais  37475.258
# 12           Paraiba  52426.918
# 13              Pará  24512.144
# 14        Pernambuco  24498.000
# 15              Piau  37803.747
# 16               Rio  45094.865
# 17          Rondonia  20285.429
# 18           Roraima  24385.074
# 19    Santa Catarina  24359.852
# 20         Sao Paulo  51121.198
# 21           Sergipe   3237.000
# 22         Tocantins  33707.885

# %%
plt.figure(figsize=(25,10))
ax=sns.barplot(data=df2,x='state',y='number',palette='Set3')
plt.grid()
for i in ax.containers:
  ax.bar_label(i)
plt.title('State Vs Number')
plt.show()
# Out:
# /tmp/ipython-input-2158674141.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df2,x='state',y='number',palette='Set3')

# %%
df[df['state']=='Amazonas']['number'].sum()
# Out:
# np.float64(30650.129)

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['Days']
# Out:
# 0       Thursday
# 1       Thursday
# 2       Thursday
# 3       Thursday
# 4       Thursday
#           ...
# 6449    Thursday
# 6450    Thursday
# 6451    Thursday
# 6452    Thursday
# 6453    Thursday
# Name: Days, Length: 6422, dtype: object

# %%
sns.countplot(x='number', hue='Days', data=df)
plt.show()

# %%
df[df['year']==2015].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3878759193.py in <cell line: 0>()
# ----> 1 df[df['year']==2015].sum()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'Days', 'day_name'], dtype='object')

# %%
plt.figure(figsize=(20,9))
sns.barplot(data=df,x='month',y='number')
# Out:
# <Axes: xlabel='month', ylabel='number'>

# %%
df['state'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)

# %%
plt.figure(figsize=(30,12))
ax=sns.barplot(data=df,x='state',y='number',palette='Set1')
for i in ax.containers:
  ax.bar_label(i)
# Out:
# /tmp/ipython-input-27853649.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df,x='state',y='number',palette='Set1')

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'Days', 'day_name'], dtype='object')

# %%
plt.figure(figsize=(30,12))
sns.lineplot(data=df,x='month',y='number')
# Out:
# <Axes: xlabel='month', ylabel='number'>

# %%
plt.figure(figsize=(30,12))

# Line plot
A = sns.lineplot(data=df, x='year', y='number', color='red', marker='o')

# Annotate points on the line
for x, y in zip(df['year'], df['number']):
    A.text(x, y, str(y), ha='center', va='bottom')

plt.grid(True)
plt.show()
