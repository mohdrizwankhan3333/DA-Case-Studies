# %%
import pandas as pd
df=pd.read_csv("/content/top-5000-youtube-channels.csv")
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
df.describe(include="all")
# Out:
#            Rank Grade Channel name Video Uploads Subscribers   Video views
# count      5000  5000         5000          5000        5000  5.000000e+03
# unique     5000     6         4993          2286        4612           NaN
# top     5,000th   B+    Thơ Nguyễn            20         --            NaN
# freq          1  2956            2            17         387           NaN
# mean        NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std         NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min         NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%         NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%         NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%         NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max         NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %%
df.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
df.shape
# Out:
# (5000, 6)

# %%
df.shape[1]
# Out:
# 6

# %%
df.shape[0]
# Out:
# 5000

# %%
z=[x for x in df.columns if x=="--"]

# %%
z
# Out:
# []

# %%
pd.options.display.float_format='{:.2f}'.format

# %%
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
import numpy as np

# %%
df=df.replace('--',np.nan, regex=True)

# %%
per_missing=df.isnull().sum()*100/len(df)

# %%
per_missing
# Out:
# Rank              0.00
# Grade             0.00
# Channel name      0.00
# Video Uploads     0.12
# Subscribers     100.00
# Video views       0.00
# dtype: float64

# %%
df['Video Uploads']=df['Video Uploads'].str.strip
df['Video Uploads']=df['Video Uploads'].dropna()

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Video views      0
# dtype: int64

# %%
df['Rank']
# Out:
# 0           1st
# 1           2nd
# 2           3rd
# 3           4th
# 4           5th
#          ...
# 4995    4,996th
# 4996    4,997th
# 4997    4,998th
# 4998    4,999th
# 4999    5,000th
# Name: Rank, Length: 5000, dtype: object

# %%
df['Rank']=df['Rank'].str[0:-2]

# %%
df['Rank'].replace (',','', )
# Out:
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#         ...
# 4995    4,996
# 4996    4,997
# 4997    4,998
# 4998    4,999
# 4999    5,000
# Name: Rank, Length: 5000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Video views    5000 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 195.4+ KB

# %%
df['Rank']=df['Rank'].str.replace(',','')

# %%
df['Rank']=df['Rank'].astype(int)

# %%
df['Grade']
# Out:
# 0       A++
# 1       A++
# 2       A++
# 3       A++
# 4       A++
#         ...
# 4995     B+
# 4996     B+
# 4997     B+
# 4998     B+
# 4999     B+
# Name: Grade, Length: 5000, dtype: object

# %%
df['Video views'].dtype
# Out:
# dtype('int64')

# %%
df['Video Uploads'].dtype
# Out:
# dtype('O')

# %%
df['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', '\xa0 ', 'A- ', 'B+ '], dtype=object)

# %%
df['Grade'] = df['Grade'].replace({'A++': 5, 'A+': 4, 'A': 3, 'A-': 2, 'B+': 1})

# %%
 df.head()
# Out:
#    Rank  Grade                Channel name  \
# 0     1    NaN                      Zee TV
# 1     2    NaN                    T-Series
# 2     3    NaN  Cocomelon - Nursery Rhymes
# 3     4    NaN                   SET India
# 4     5    NaN                         WWE
#
#                                        Video Uploads  Video views
# 0  <bound method StringMethods.strip of <pandas.c...  20869786591
# 1  <bound method StringMethods.strip of <pandas.c...  47548839843
# 2  <bound method StringMethods.strip of <pandas.c...   9793305082
# 3  <bound method StringMethods.strip of <pandas.c...  22675948293
# 4  <bound method StringMethods.strip of <pandas.c...  26273668433

# %%
df.sort_values(by='Video Uploads', ascending=False).head(5)

# %%
df.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Video views'], dtype='object')

# %%
df.groupby('Grade')['Video Uploads'].count()
# Out:
# Series([], Name: Video Uploads, dtype: int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='Grade', y='Video Uploads', data=df)
plt.show()

# %%
sns.barplot(x='Grade', y='Video views', data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>
